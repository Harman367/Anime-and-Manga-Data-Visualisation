# %%
import pandas as pd

df = pd.read_csv("Dataset/anime.csv")

df.shape[0]
# Out:
# 24165

# %%
df.demographics.unique()
# Out:
# array(["['Shounen']", '[]', "['Seinen']", "['Shoujo']", "['Josei']",
#        "['Kids']", "['Kids', 'Shounen']", "['Kids', 'Seinen']",
#        "['Kids', 'Shoujo']", "['Josei', 'Shoujo']",
#        "['Kids', 'Seinen', 'Shoujo']", "['Seinen', 'Shounen']"],
#       dtype=object)

# %%
df.themes.unique()
# Out:
# array(["['Military']", '[]', "['Gore', 'Military', 'Survival']",
#        "['Psychological', 'Time Travel']", "['Romantic Subtext']",
#        "['Mecha', 'Military', 'Super Power']", "['Mythology']",
#        "['Mecha', 'Military', 'School', 'Super Power']",
#        "['Psychological']", "['School']", "['Music', 'School']",
#        "['Adult Cast', 'Space']", "['Historical']", "['Super Power']",
#        "['Parody', 'Super Power']", "['School', 'Team Sports']",
#        "['Psychological', 'Survival']", "['Mecha']",
#        "['Psychological', 'Romantic Subtext', 'School']", "['Childcare']",
#        "['Organized Crime']", "['Mecha', 'Psychological']",
#        "['Gore', 'Psychological']", "['Historical', 'Samurai']",
#        "['Gag Humor', 'Historical', 'Parody', 'Samurai']",
#        "['Isekai', 'Reincarnation']",
#        "['Adult Cast', 'Detective', 'Psychological']",
#        "['Mahou Shoujo', 'Psychological']", "['Gag Humor', 'School']",
# ...

# %%
df = df.drop(df[df.sfw == False].index)

df.shape[0]
# Out:
# 22666

# %%
df.sfw.describe()
# Out:
# count     22666
# unique        1
# top        True
# freq      22666
# Name: sfw, dtype: object

# %%
df.dtypes
# Out:
# anime_id              int64
# title                object
# type                 object
# score               float64
# scored_by             int64
# status               object
# episodes            float64
# start_date           object
# end_date             object
# source               object
# members               int64
# favorites             int64
# episode_duration     object
# total_duration       object
# rating               object
# sfw                    bool
# approved               bool
# created_at           object
# updated_at           object
# start_year          float64
# start_season         object
# real_start_date      object
# real_end_date        object
# broadcast_day        object
# broadcast_time       object
# genres               object
# themes               object
# demographics         object
# studios              object
# producers            object
# licensors            object
# synopsis             object
# background           object
# ...

# %%
df['anime_id'][0]
# Out:
# 5114

# %%
for anime in df['anime_id']:
    print(anime)
# Out:
# 5114
# 11061
# 38524
# 9253
# 28851
# 32281
# 2904
# 40028
# 199
# 1575
# 1535
# 40748
# 23273
# 35760
# 21
# 1
# 16498
# 38000
# 37510
# 30276
# 32935
# 33352
# 25777
# 4181
# 37779
# 28891
# 431
# 2001
# 164
# 40456
# 47778
# 37521
# 40591
# 32182
# 34599
# 20583
# 50265
# 11741
# 30654
# 48583
# 37999
# 37991
# 31933
# 32
# 22535
# 26055
# 205
# 36098
# 30
# 31043
# 918
# 9989
# 12355
# 45576
# 13601
# 9756
# 33255
# 245
# 5081
# 31240
# 38329
# 1735
# 38691
# 39535
# 37450
# 32937
# 17074
# 39587
# 40776
# 19
# 10087
# 42203
# 38040
# 43608
# 30484
# 38883
# 39551
# 28701
# 777
# 578
# 523
# 38826
# 33486
# 48736
# 7311
# 37105
# 437
# 28171
# 36649
# 10165
# 23847
# 33
# 11577
# 42897
# 28223
# 34612
# 24415
# 2251
# 457
# 30503
# 10408
# 37520
# 263
# 31758
# 28977
# 30831
# 39547
# 16894
# 392
# 22297
# 19815
# 813
# 9969
# 4224
# 22789
# 853
# 31757
# 121
# 37430
# 24833
# 18115
# 36456
# 33674
# 34572
# 25781
# 40834
# 11843
# 41487
# 6547
# 41025
# 6746
# 40852
# 32867
# ...
